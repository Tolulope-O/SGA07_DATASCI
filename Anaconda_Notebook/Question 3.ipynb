# %% [markdown]
# ## Morning Challenge
# ### Question 3

# %% [markdown]
# ### Write a program should print out all the numbers from 1 to 300, but prints out Fizz instead if the number is divisible by 3, Buzz instead if the number is divisible by 5, and FizzBuzz if the number is divisible by 3 and 5. What is the total number of numbers that is either Fizzed, Buzzed, or FizzBuzzed?

# %%
count_fizz = 0
count_buzz = 0
count_fizzbuzz = 0

number = (range(1, 301))
for n in number:
    if n % 3 == 0 and n % 5  == 0:
        count_fizzbuzz = count_fizzbuzz + 1
        print('count_fizzbuzz')
    elif n % 3 == 0:
        count_fizz = count_fizz + 1
        print('count_fizz')
    elif n % 5 == 0:
        count_buzz = count_buzz + 1
        print('count_buzz')
    else:
        print(n)
# Out:
# 1
# 2
# count_fizz
# 4
# count_buzz
# count_fizz
# 7
# 8
# count_fizz
# count_buzz
# 11
# count_fizz
# 13
# 14
# count_fizzbuzz
# 16
# 17
# count_fizz
# 19
# count_buzz
# count_fizz
# 22
# 23
# count_fizz
# count_buzz
# 26
# count_fizz
# 28
# 29
# count_fizzbuzz
# 31
# 32
# count_fizz
# 34
# count_buzz
# count_fizz
# 37
# 38
# count_fizz
# count_buzz
# 41
# count_fizz
# 43
# 44
# count_fizzbuzz
# 46
# 47
# count_fizz
# 49
# count_buzz
# count_fizz
# 52
# 53
# count_fizz
# count_buzz
# 56
# count_fizz
# 58
# 59
# count_fizzbuzz
# 61
# 62
# count_fizz
# 64
# count_buzz
# count_fizz
# 67
# 68
# count_fizz
# count_buzz
# 71
# count_fizz
# 73
# 74
# count_fizzbuzz
# 76
# 77
# count_fizz
# 79
# count_buzz
# count_fizz
# 82
# 83
# count_fizz
# count_buzz
# 86
# count_fizz
# 88
# 89
# count_fizzbuzz
# 91
# 92
# count_fizz
# 94
# count_buzz
# count_fizz
# 97
# 98
# count_fizz
# count_buzz
# 101
# count_fizz
# 103
# 104
# count_fizzbuzz
# 106
# 107
# count_fizz
# 109
# count_buzz
# count_fizz
# ...

# %%
print ('fizz', count_fizz)
print ('buzz', count_buzz)
print ('fizzbuzz', count_fizzbuzz)
# Out:
# fizz 80
# buzz 40
# fizzbuzz 20
